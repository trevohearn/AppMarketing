# %%
import CleanData
import pandas as pd

df_g = pd.read_csv('Data/google-play-store-apps/googleplaystore.csv')

# %%
CleanData.

# %%
df = CleanData.cleanDFG(df_g)
# Out:
# different combination of letters and numbers: Varies with device
# different combination of letters and numbers: Varies with device
# different combination of letters and numbers: Varies with device
# different combination of letters and numbers: Varies with device
# different combination of letters and numbers: Varies with device
# different combination of letters and numbers: Varies with device
# different combination of letters and numbers: Varies with device
# different combination of letters and numbers: Varies with device
# different combination of letters and numbers: Varies with device
# different combination of letters and numbers: Varies with device
# different combination of letters and numbers: Varies with device
# different combination of letters and numbers: Varies with device
# different combination of letters and numbers: Varies with device
# different combination of letters and numbers: Varies with device
# ...

# %%
df.iloc[0]
# Out:
# App                   Photo Editor & Candy Camera & Grid & ScrapBook
# Category                                              ART_AND_DESIGN
# Rating                                                           4.1
# Reviews                                                          159
# Size                                                         1.9e+07
# Installs                                                       10000
# Type                                                            Free
# Price                                                              0
# Content Rating                                              Everyone
# Genres                                                  Art & Design
# Last Updated                                     2018-01-07 00:00:00
# Current Ver                                                    1.0.0
# Android Ver                                             4.0.3 and up
# ContentRatingValue                                                 0
# ...

# %%
df2 = CleanData.createNameFeatures(df, 'App')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-acd60e403aa2> in <module>
# ----> 1 df2 = CleanData.createNameFeatures(df, 'App')
#
# AttributeError: module 'CleanData' has no attribute 'createNameFeatures'

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'ContentRatingValue'],
#       dtype='object')

# %%
CleanData.
# Out:
# App                           object
# Category                      object
# Rating                       float64
# Reviews                      float64
# Size                         float64
# Installs                       int64
# Type                          object
# Price                        float64
# Content Rating                object
# Genres                        object
# Last Updated          datetime64[ns]
# Current Ver                   object
# Android Ver                   object
# ContentRatingValue             int64
# dtype: object

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews        Size  Installs  Type  Price Content Rating  \
# 0     159.0  19000000.0     10000  Free    0.0       Everyone
# 1     967.0  14000000.0    500000  Free    0.0       Everyone
# 2   87510.0   8700000.0      5000  Free    0.0       Everyone
# 3  215644.0  25000000.0     50000  Free    0.0           Teen
# 4     967.0   2800000.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# ...

# %%
word = 'apple'
countLetters(word)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-87779c3ce51a> in <module>
#       1 word = 'apple'
# ----> 2 countLetters(word)
#
# NameError: name 'countLetters' is not defined

# %%
test = {'1' : 0 , '2' : 0, '3' : 0}
for t in test:
    df[t] = test[t]

# %%
df2.Installs.mean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-02c67c797d18> in <module>
# ----> 1 df2.Installs.mean
#
# NameError: name 'df2' is not defined

# %%
alphabet = {'a' : 0, 'e' : 0,'i' : 0, 'o' : 0, 'u' : 0,
        'b' : 0, 'c' : 0, 'd' : 0, 'f' : 0,'g' : 0,'h' : 0 ,'j' : 0, 'k' : 0,
        'l' : 0, 'm' : 0, 'n' : 0, 'p' : 0, 'q' : 0,'r' : 0,'s' : 0,'t' : 0,'v' : 0,
        'w' : 0,'x' : 0,'y' : 0 ,'z' : 0}
for a in alphabet:
    df[a] = alphabet[a]

# %%
df['nameLength'] = df['App'].apply(lambda x : len(x))

# %%
df['wordLength'] = df['App'].apply(lambda x: len(x.split(' ')))

# %%
word = 'apple'
word.count('p')
# Out:
# 2

# %%
df[a] = df['App'].apply(lambda x: x.count(a) for a in alphabet)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-2bd6d7c0fdf9> in <module>
# ----> 1 df[a] = df['App'].apply(lambda x: x.count(a) for a in alphabet)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# TypeError: 'generator' object is not callable

# %%
def countAlphabet(x):
    alphabet = {'a' : 0, 'e' : 0,'i' : 0, 'o' : 0, 'u' : 0,
        'b' : 0, 'c' : 0, 'd' : 0, 'f' : 0,'g' : 0,'h' : 0 ,'j' : 0, 'k' : 0,
        'l' : 0, 'm' : 0, 'n' : 0, 'p' : 0, 'q' : 0,'r' : 0,'s' : 0,'t' : 0,'v' : 0,
        'w' : 0,'x' : 0,'y' : 0 ,'z' : 0}
    for a in alphabet:
        df[a] = x.count(a)

# %%
for a in alphabet:
    df[a] = df.App.apply(lambda x : x.lower().count(a))

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews        Size  Installs  Type  Price Content Rating  \
# 0     159.0  19000000.0     10000  Free    0.0       Everyone
# 1     967.0  14000000.0    500000  Free    0.0       Everyone
# 2   87510.0   8700000.0      5000  Free    0.0       Everyone
# 3  215644.0  25000000.0     50000  Free    0.0           Teen
# 4     967.0   2800000.0    100000  Free    0.0       Everyone
#
#                       Genres  ...  r  s  t  v  w  x  y  z  nameLength  \
# ...

# %%
5 + 6 + 5+ 6 + 4 + 9
# Out:
# 35

# %%
df.iloc[0]
# Out:
# App                   Photo Editor & Candy Camera & Grid & ScrapBook
# Category                                              ART_AND_DESIGN
# Rating                                                           4.1
# Reviews                                                          159
# Size                                                         1.9e+07
# Installs                                                       10000
# Type                                                            Free
# Price                                                              0
# Content Rating                                              Everyone
# Genres                                                  Art & Design
# Last Updated                                     2018-01-07 00:00:00
# Current Ver                                                    1.0.0
# Android Ver                                             4.0.3 and up
# ContentRatingValue                                                 0
# ...

# %%
4+2+2+5+1+3+3+1+1+1+1+1+2+4+1+2+1
# Out:
# 35

# %%
count = 0
for a in alphabet:
    count += 'PhotoEditorCandyCameraGridScrapBook'.count(a)
count
# Out:
# 28

# %%
w = 'Photo Editor & Candy Camera & Grid & ScrapBook'

# %%
syllables(w)
# Out:
# 13

# %%
df['syllables'] = df.App.apply(syllables)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews        Size  Installs  Type  Price Content Rating  \
# 0     159.0  19000000.0     10000  Free    0.0       Everyone
# 1     967.0  14000000.0    500000  Free    0.0       Everyone
# 2   87510.0   8700000.0      5000  Free    0.0       Everyone
# 3  215644.0  25000000.0     50000  Free    0.0           Teen
# 4     967.0   2800000.0    100000  Free    0.0       Everyone
#
#                       Genres  ...  s  t  v  w  x  y  z  nameLength  \
# ...
