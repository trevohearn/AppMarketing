# %%
import AppAnalysis as a

genrestats = a.Appanalysis('Dating', 'Facebook')
genrestats
# Out:
# Input Genre:
# Input App Name
# Facebook
# in name features
# /Users/trevohearn/Documents/AppMarketing/AppAnalysis.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['Label'] = agc_standard.labels_
# /Users/trevohearn/Documents/AppMarketing/AppAnalysis.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d['Label'] = agc_standard.labels_
# /Users/trevohearn/Documents/AppMarketing/AppAnalysis.py:54: SettingWithCopyWarning:
# ...

# %%
genrestats.keys()
# Out:
# dict_keys(['Tools', 'Entertainment', 'Education', 'Medical', 'Business', 'Productivity', 'Sports', 'Personalization', 'Communication', 'Lifestyle', 'Finance', 'Action', 'Health & Fitness', 'Photography', 'Social', 'News & Magazines', 'Shopping', 'Travel & Local', 'Dating', 'Books & Reference'])

# %%
genrestats['Dating'].keys()
# Out:
# dict_keys(['ymean', 'deviation_of_means', 'means', 'mean_of_means', 'df_genre'])

# %%
df_dating = genrestats['Dating']['df_genre']

# %%
df_dating.head()
# Out:
#                                   App Category  Rating   Reviews        Size  \
# 503  Once - Quality Matches Every day   DATING   4.400  222888.0  21000000.0
# 556  Once - Quality Matches Every day   DATING   4.400  222888.0  21000000.0
# 643      i miss you quotes and photos   DATING   0.001       0.0   5000000.0
# 648                    Iraq love chat   DATING   0.001      14.0   5000000.0
#
#      Installs  Type  Price Content Rating  Genres  ...  r  s  t  v  w  x  y  \
# 503      1000  Free    0.0     Mature 17+  Dating  ...  1  1  2  1  0  0  3
# 556      1000  Free    0.0     Mature 17+  Dating  ...  1  1  2  1  0  0  3
# 643       100  Free    0.0       Everyone  Dating  ...  0  4  2  0  0  0  1
# 648        50  Free    0.0           Teen  Dating  ...  1  0  1  1  0  0  0
#
#      z  syllables  Label
# 503  0         11      9
# 556  0         11      9
# 643  0          8      9
# 648  0          5      9
#
# [4 rows x 44 columns]

# %%
# %matplotlib inline
import matplotlib.pylab as plt
import seaborn as sns

name_clusters = ['cluster 0', 'cluster 1','cluster 2','cluster 3','cluster 4','cluster 5',
                   'cluster 6','cluster 7','cluster 8','cluster 9',]

# for cluster, g in enumerate(genrestats):
#     plt.bar(x=list(range(10)),
#                 y=g['means'], yerr=g['deviation_of_means'])

# %%
type(genrestats['Dating']['means'][0])
# Out:
# float

# %%
genrestats['Dating']['deviation_of_means']
# Out:
# 0.7554481699579051

# %%
plt.bar(x=name_clusters, height=genrestats['Dating']['means'])
plt.xticks(rotation=70)
plt.ylabel('Average Rating')
plt.title('Average Rating by Cluster')
plt.show();
print(genrestats['Dating']['ymean'])
# Out:
# 2.7938064516129026

# %%
font = {'family' : 'Times New Roman',
        'weight' : 'normal',
        'size'   : 20}

plt.rc('font', **font)

# %%
allmeans = []
ymeans = []
for g in genrestats:
    allmeans.append(genrestats[g]['mean_of_means'])
    ymeans.append(genrestats[g]['ymean'])
    
w = 0.3
f, ax = plt.subplots(figsize=(20,5))
ax = plt.bar(list(genrestats.keys()), allmeans, width=0.4, color='red', label='Overall', alpha=1)
ax = plt.bar(list(genrestats.keys()), ymeans, width=-0.4, color='gray', label='Yours', alpha=1)
plt.xticks(rotation=63)
plt.title('Your App Name Rating Relative to Each Genre (less red the better)')
# ax1.legend('Overall')
# ax2.legend('Yours')
plt.figure(figsize=(1,15))
plt.show();

# %%
# ax = plt.subplot(111)
# w = 0.3
# ax.bar(x-w, y, width=w, color='b', align='center')
# ax.bar(x, z, width=w, color='g', align='center')
# ax.bar(x+w, k, width=w, color='r', align='center')
# ax.xaxis_date()
# ax.autoscale(tight=True)

# %%
# import matplotlib.pyplot as plt

# f, ax = plt.subplots(figsize=(18,5)) # set the size that you'd like (width, height)
# plt.bar([1,2,3,4], [0.1,0.2,0.3,0.4], label = 'first bar')
# plt.bar([10,11,12,13], [0.4,0.3,0.2,0.1], label = 'second bar')
# ax.legend(fontsize = 14)
